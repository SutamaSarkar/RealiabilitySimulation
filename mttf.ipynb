# %% [markdown]
# <a href="https://colab.research.google.com/github/SutamaSarkar/RealiabilitySimulation/blob/main/mttf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import math

N=10000000
theta=5000
beta =2


def calculate_weibull_mttf(beta, theta):
     mttf = theta*(math.gamma(1 + 1 / beta))
     return mttf
mttf=calculate_weibull_mttf(beta, theta)
print(f"Analytical MTTF: {calculate_weibull_mttf(2, 5000):.2f}")

tmax=10861.5965677990


sum=0
a=0

for i in range (1,N):
      x= random.uniform(a,b)
      y=math.exp((-x*tmax)/theta)
      sum= sum+y
      mttfa=(tmax/N)*sum
print("Experimental MTTF ",mttfa)


error=abs(((mttfa-mttf)/mttf)*100)
print("Percentage Error ",error)
# Out:
# Analytical MTTF: 4431.13
# Experimental MTTF  4431.831209966726
# Percentage Error  0.01572018820304607
